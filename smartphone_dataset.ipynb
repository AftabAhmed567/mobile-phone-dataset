# %%
# Step 1: Import the necessary library
import pandas as pd

# Step 2: Load the CSV file
# Upload the file manually by clicking on the file icon on the left and selecting 'Upload'
# or use the following code if the file is already uploaded or available at a specific path
df = pd.read_csv('smartphones.csv')  # Replace 'example.csv' with your file name

# Step 3: Perform operations
# Display the first few rows of the DataFrame
print(df.head())

# Display basic information about the DataFrame
print(df.info())

# Describe the DataFrame to get summary statistics
print(df.describe())

# Additional operations can be added here
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price
# 0   8.0    256.0  Yellow  Yes       231.60
# 1   4.0    128.0    Blue  Yes       279.00
# 2   4.0    128.0    Blue  Yes       179.01
# 3   6.0    128.0    Gray  Yes       279.99
# 4  12.0    512.0   White  Yes       799.00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1816 entries, 0 to 1815
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Smartphone   1816 non-null   object
# ...

# %%
print(df.tail())
# Out:
#                                             Smartphone   Brand          Model  \
# 1811             Xiaomi Redmi Note 8 4/64GB Azul Libre  Xiaomi   Redmi Note 8
# 1812   Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre  Xiaomi  Redmi Note 8T
# 1813          Xiaomi Redmi Note 9 4/128GB Blanco Libre  Xiaomi   Redmi Note 9
# 1814   Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre  Xiaomi        Note 9S
# 1815  Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre  Xiaomi        Note 9S
#
#       RAM  Storage  Color Free  Final Price
# 1811  4.0     64.0   Blue  Yes       249.01
# 1812  4.0    128.0   Blue  Yes       200.00
# 1813  4.0    128.0  White  Yes       269.00
# 1814  4.0     64.0   Gray  Yes       211.00
# 1815  6.0    128.0   Gray  Yes       289.00

# %%
print(df['Smartphone'])
print(df.head())
# Out:
# 0                     Realme C55 8/256GB Sunshower Libre
# 1               Samsung Galaxy M23 5G 4/128GB Azul Libre
# 2           Motorola Moto G13 4/128GB Azul Lavanda Libre
# 3               Xiaomi Redmi Note 11S 6/128GB Gris Libre
# 4                Nothing Phone (2) 12/512GB Blanco Libre
#                               ...
# 1811               Xiaomi Redmi Note 8 4/64GB Azul Libre
# 1812     Xiaomi Redmi Note 8T 4/128GB Azul Estelar Libre
# 1813            Xiaomi Redmi Note 9 4/128GB Blanco Libre
# 1814     Xiaomi Redmi Note 9S 4/64GB Dual SIM Gris Libre
# 1815    Xiaomi Redmi Note 9S 6/128GB Dual SIM Gris Libre
# Name: Smartphone, Length: 1816, dtype: object
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# ...

# %%
# Select rows by index
print(df.iloc[1])  # First row
# Out:
# Smartphone     Samsung Galaxy M23 5G 4/128GB Azul Libre
# Brand                                           Samsung
# Model                                        Galaxy M23
# RAM                                                 4.0
# Storage                                           128.0
# Color                                              Blue
# Free                                                Yes
# Final Price                                       279.0
# Name: 1, dtype: object

# %%
print(df.iloc[1:5])  # Second to fifth rows
# Out:
#                                      Smartphone     Brand           Model  \
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage  Color Free  Final Price
# 1   4.0    128.0   Blue  Yes       279.00
# 2   4.0    128.0   Blue  Yes       179.01
# 3   6.0    128.0   Gray  Yes       279.99
# 4  12.0    512.0  White  Yes       799.00

# %%
# Rename columns
df_renamed = df.rename(columns={'Color': 'red'})  # Replace 'old_name' and 'new_name' with actual
print(df.head())
# Out:
#                                      Smartphone     Brand           Model  \
# 0            Realme C55 8/256GB Sunshower Libre    Realme             C55
# 1      Samsung Galaxy M23 5G 4/128GB Azul Libre   Samsung      Galaxy M23
# 2  Motorola Moto G13 4/128GB Azul Lavanda Libre  Motorola        Moto G13
# 3      Xiaomi Redmi Note 11S 6/128GB Gris Libre    Xiaomi  Redmi Note 11S
# 4       Nothing Phone (2) 12/512GB Blanco Libre   Nothing       Phone (2)
#
#     RAM  Storage   Color Free  Final Price
# 0   8.0    256.0  Yellow  Yes       231.60
# 1   4.0    128.0    Blue  Yes       279.00
# 2   4.0    128.0    Blue  Yes       179.01
# 3   6.0    128.0    Gray  Yes       279.99
# 4  12.0    512.0   White  Yes       799.00

# %%
# Plot a histogram of a column
# Import the matplotlib library for visualization
import matplotlib.pyplot as plt

# Plot a histogram of a column
df['Free'].hist()  # Replace 'column_name' with the actual column name
plt.show()

# Plot a scatter plot
df.plot.scatter(x='Free', y='Final Price')  # Replace 'column1' and 'column2' with actual column names
plt.show()

# %%
# Plot all columns
df.plot(kind='line', subplots=True, layout=(len(df.columns), 1), figsize=(10, 20), sharex=False)
plt.tight_layout()
plt.show()
